# %%
import pandas as pd
import os
import random
import matplotlib.pyplot as plt
path = "/home/foxcornio/.cache/kagglehub/datasets/mlg-ulb/creditcardfraud/versions/3"
file_path = os.path.join(path, 'creditcard.csv')
data = pd.read_csv(file_path) # Creamos el dataset leyendo el csv

y_real = data['Class'].tolist() # Creamos la lista de datos

print(f"Total de registros cargados: {len(y_real)}") # imprimimos el conteo de y_real
# Out:
# Total de registros cargados: 284807

# %%
y_pred = [] # Almacenara falsos positivos y falsos negativos
for valor in y_real: # Almacenamos los datos mediante un ciclo for 
    if random.random() < 0.95:
        y_pred.append(valor)
    else:
        y_pred.append(1-valor)
data.tail(1)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 284806  172792.0 -0.533413 -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7       V8       V9  ...       V21       V22       V23  \
# 284806  1.577006 -0.41465  0.48618  ...  0.261057  0.643078  0.376777
#
#              V24       V25       V26       V27       V28  Amount  Class
# 284806  0.008797 -0.473649 -0.818267 -0.002415  0.013649   217.0      0
#
# [1 rows x 31 columns]

# %%
plt.hist(y_real, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plt.hist(y_real, y_pred)
#
# File /var/www/html/cursos/curso-python/projects/dataScience/.venv/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...
